# %% [markdown]
# ### The analysis will be on a dataset of used cars listings from eBay German

# %% [markdown]
# The dataset was modified version downloaded from Kaggle.
#
# The data dictionary provided with data is as follows:
# - dateCrawled - When this ad was first crawled. All field-values are taken from this date.
# - name - Name of the car.
# - seller - Whether the seller is private or a dealer.
# - offerType - The type of listing
# - price - The price on the ad to sell the car.
# - abtest - Whether the listing is included in an A/B test.
# - vehicleType - The vehicle Type.
# - yearOfRegistration - The year in which which year the car was first registered.
# - gearbox - The transmission type.
# - powerPS - The power of the car in PS.
# - model - The car model name.
# - kilometer - How many kilometers the car has driven.
# - monthOfRegistration - The month in which which year the car was first registered.
# - fuelType - What type of fuel the car uses.
# - brand - The brand of the car.
# - notRepairedDamage - If the car has a damage which is not yet repaired.
# - dateCreated - The date on which the eBay listing was created.
# - nrOfPictures - The number of pictures in the ad.
# - postalCode - The postal code for the location of the vehicle.
# - lastSeenOnline - When the crawler saw this ad last online.
#
# We will do some data cleaning and exploratory analysis of this data.

# %%
import pandas as pd
import numpy as np
autos = pd.read_csv("autos.csv",encoding = "Latin-1")

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# #### There are some columns with null values and dirty text structure. We will need to investigate how to deep with null value rows and clean up the string columns

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# - Made updates to columns names to make titles more readable and indicative

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'num_photos', 'postal_code',
       'last_seen']

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# #### Exploratory analysis to see patterns of the data and investigate:
# - Any columns stored as string can be converted to numbers
# - Any columns that has few unique value that can be dropped
# - Any columns need further cleaning

# %%
autos.describe(include="all")
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-30 19:48:02  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %%
autos["seller"].value_counts()
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos['offer_type'].value_counts()
# Out:
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64

# %%
autos['num_photos'].value_counts()
# Out:
# 0    50000
# Name: num_photos, dtype: int64

# %%
autos.loc[autos["seller"] == 'gewerblich']
# Out:
#              date_crawled                                         name  \
# 7738  2016-03-15 18:06:22  Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
#
#           seller offer_type price  ab_test vehicle_type  registration_year  \
# 7738  gewerblich    Angebot  $100  control        kombi               2000
#
#       gearbox  power_ps   model   odometer  registration_month fuel_type  \
# 7738  manuell         0  megane  150,000km                   8    benzin
#
#         brand unrepaired_damage           ad_created  num_photos  postal_code  \
# 7738  renault               NaN  2016-03-15 00:00:00           0        65232
#
#                 last_seen
# 7738  2016-04-06 17:15:37

# %%
autos.loc[autos["offer_type"] == 'Gesuch']
# Out:
#               date_crawled                  name  seller offer_type price  \
# 17541  2016-04-03 15:48:33  Suche_VW_T5_Multivan  privat     Gesuch    $0
#
#       ab_test vehicle_type  registration_year gearbox  power_ps        model  \
# 17541    test          bus               2005     NaN         0  transporter
#
#         odometer  registration_month fuel_type       brand unrepaired_damage  \
# 17541  150,000km                   0       NaN  volkswagen               NaN
#
#                 ad_created  num_photos  postal_code            last_seen
# 17541  2016-04-03 00:00:00           0        29690  2016-04-05 15:16:06

# %% [markdown]
# #### Outliers with only one record of unique value:
# - "seller": One record of commerical car while all other 49999 is private
# - "offer_type": One record of petition offer while all other 49999 are offers
# - "num_photos": The column doesn't have meaningful value
# For the efficiency of analysis, we could just drop those

# %%
autos.drop(['seller','offer_type','num_photos'], axis=1)
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %% [markdown]
# #### `price` and `odometer` columns are stored as string. They should be converted as numeric values

# %%
autos["price"] = (autos["price"]
                          .str.replace("$","")
                          .str.replace(",","")
                          .astype(int)
                          )
autos["price"].head()
# Out:
# 0    5000
# 1    8500
# 2    8990
# 3    4350
# 4    1350
# Name: price, dtype: int64

# %%
autos["odometer"] = (autos["odometer"]
                    .str.replace('km','')
                    .str.replace(',','')
                    .astype(int)
                    )
autos.rename({'odometer':'odometer_km'}, axis=1, inplace=True)
autos["odometer_km"].head()
# Out:
# 0    150000
# 1    150000
# 2     70000
# 3     70000
# 4    150000
# Name: odometer_km, dtype: int64

# %% [markdown]
# #### Investigate more on `price` and `odometer` unique values to see any further adjustment

# %%
autos["price"].unique().shape

autos["price"].describe()

autos['price'].value_counts().head(30)
# Out:
# 0       1421
# 500      781
# 1500     734
# 2500     643
# 1000     639
# 1200     639
# 600      531
# 800      498
# 3500     498
# 2000     460
# 999      434
# 750      433
# 900      420
# 650      419
# 850      410
# 700      395
# 4500     394
# 300      384
# 2200     382
# 950      379
# 1100     376
# 1300     371
# 3000     365
# 550      356
# 1800     355
# 5500     340
# 1250     335
# 350      335
# 1600     327
# 1999     322
# Name: price, dtype: int64

# %%
autos['price'].value_counts().sort_index(ascending=True).head(30)
# Out:
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# 13       2
# 14       1
# 15       2
# 17       3
# 18       1
# 20       4
# 25       5
# 29       1
# 30       7
# 35       1
# 40       6
# 45       4
# 47       1
# 49       4
# 50      49
# 55       2
# 59       1
# 60       9
# 65       5
# 66       1
# Name: price, dtype: int64

# %%
autos['price'].value_counts().sort_index(ascending=False).head(30)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# 259000      1
# 250000      1
# 220000      1
# 198000      1
# 197000      1
# 194000      1
# 190000      1
# 180000      1
# 175000      1
# 169999      1
# 169000      1
# 163991      1
# 163500      1
# 155000      1
# 151990      1
# Name: price, dtype: int64

# %% [markdown]
# #### There are prices with extremely high values of more than 1M, extremely low values of less than 10, and 1421 records of 0 price, which is less than 5% of total records.
# Considering the sales are made from bidding offers, the price could start from $1 dollar. But we will drop the rows with extremely high prices of more htan 350000 and 0 prices.

# %%
autos = autos[autos["price"].between(1,350000)]
autos["price"].describe()
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price, dtype: float64

# %% [markdown]
# #### The values of mileage are round up and they could be the range of preset options.
# Majority of the cars have high mileage.

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    31414
# 125000     5057
# 100000     2115
# 90000      1734
# 80000      1415
# 70000      1217
# 60000      1155
# 50000      1012
# 5000        836
# 40000       815
# 30000       780
# 20000       762
# 10000       253
# Name: odometer_km, dtype: int64

# %% [markdown]
# #### Explore the date columns
# There are three columns of date values that are stored as string. We will investigate to learn more about the date values.
# - date_crawled
# - ad_created
# - last_seen
# - registration_year
# - registration_month

# %%
autos[["date_crawled","ad_created","last_seen"]][2:10]
# Out:
#           date_crawled           ad_created            last_seen
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50
# 5  2016-03-21 13:47:45  2016-03-21 00:00:00  2016-04-06 09:45:21
# 6  2016-03-20 17:55:21  2016-03-20 00:00:00  2016-03-23 02:48:59
# 7  2016-03-16 18:55:19  2016-03-16 00:00:00  2016-04-07 03:17:32
# 8  2016-03-22 16:51:34  2016-03-22 00:00:00  2016-03-26 18:18:10
# 9  2016-03-16 13:47:02  2016-03-16 00:00:00  2016-04-06 10:46:35

# %%
(autos["date_crawled"]
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
)
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %% [markdown]
# - The data was mostly crawled on March and April 2016. The data is mostly distributed evenly among all dates.

# %%
(autos["ad_created"]
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
)
# Out:
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
# 2015-12-30    0.000021
# 2016-01-03    0.000021
# 2016-01-07    0.000021
# 2016-01-10    0.000041
# 2016-01-13    0.000021
# 2016-01-14    0.000021
# 2016-01-16    0.000021
# 2016-01-22    0.000021
# 2016-01-27    0.000062
# 2016-01-29    0.000021
# 2016-02-01    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-07    0.000021
# 2016-02-08    0.000021
# 2016-02-09    0.000021
# 2016-02-11    0.000021
# 2016-02-12    0.000041
# 2016-02-14    0.000041
# 2016-02-16    0.000021
# 2016-02-17    0.000021
# 2016-02-18    0.000041
# 2016-02-19    0.000062
# 2016-02-20    0.000041
# 2016-02-21    0.000062
#                 ...
# 2016-03-09    0.033151
# 2016-03-10    0.031895
# 2016-03-11    0.032904
# 2016-03-12    0.036755
# 2016-03-13    0.017008
# 2016-03-14    0.035190
# 2016-03-15    0.034016
# 2016-03-16    0.030125
# 2016-03-17    0.031278
# ...

# %% [markdown]
# - There are a few ads that are created a long time ago.

# %%
(autos["last_seen"]
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
)
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %% [markdown]
# - The ads' last view date by the crawler skews heavily on the last few days of crawling period, indicating that most cars ads still remain unsold at the end of crawling.

# %%
autos["registration_year"].value_counts().sort_index().head(20)
# Out:
# 1000    1
# 1001    1
# 1111    1
# 1800    2
# 1910    5
# 1927    1
# 1929    1
# 1931    1
# 1934    2
# 1937    4
# 1938    1
# 1939    1
# 1941    2
# 1943    1
# 1948    1
# 1950    3
# 1951    2
# 1952    1
# 1953    1
# 1954    2
# Name: registration_year, dtype: int64

# %%
(~autos["registration_year"].between(1910,2016)).sum() / autos.shape[0]
# Out:
# 0.038793369710697

# %% [markdown]
# There are a few records with invalid registration year way before and even after the listing is created. Considering these are just less than 4% of total records we can remove those.

# %%
autos = autos[autos["registration_year"].between(1910,2016)]
autos["registration_year"].value_counts(normalize=True).head(30)
# Out:
# 2000    0.067608
# 2005    0.062895
# 1999    0.062060
# 2004    0.057904
# 2003    0.057818
# 2006    0.057197
# 2001    0.056468
# 2002    0.053255
# 1998    0.050620
# 2007    0.048778
# 2008    0.047450
# 2009    0.044665
# 1997    0.041794
# 2011    0.034768
# 2010    0.034040
# 1996    0.029412
# 2012    0.028063
# 1995    0.026285
# 2016    0.026135
# 2013    0.017202
# 2014    0.014203
# 1994    0.013474
# 1993    0.009104
# 2015    0.008397
# 1992    0.007926
# 1990    0.007433
# 1991    0.007262
# 1989    0.003727
# 1988    0.002892
# 1985    0.002035
# Name: registration_year, dtype: float64

# %% [markdown]
# - Most of the cars were registered after 1990

# %% [markdown]
# #### Since brand would be a common differentiator for cars. We will explore the aggregated value by brand.

# %%
autos["brand"].unique().shape
# Out:
# (40,)

# %%
autos["brand"].value_counts(normalize=True)
# Out:
# volkswagen        0.211264
# bmw               0.110045
# opel              0.107581
# mercedes_benz     0.096463
# audi              0.086566
# ford              0.069900
# renault           0.047150
# peugeot           0.029841
# fiat              0.025642
# seat              0.018273
# skoda             0.016409
# nissan            0.015274
# mazda             0.015188
# smart             0.014160
# citroen           0.014010
# toyota            0.012703
# hyundai           0.010025
# sonstige_autos    0.009811
# volvo             0.009147
# mini              0.008762
# mitsubishi        0.008226
# honda             0.007840
# kia               0.007069
# alfa_romeo        0.006641
# porsche           0.006127
# suzuki            0.005934
# chevrolet         0.005698
# chrysler          0.003513
# dacia             0.002635
# daihatsu          0.002506
# jeep              0.002271
# subaru            0.002142
# land_rover        0.002099
# saab              0.001649
# ...

# %% [markdown]
# The top 5 brands occupie more than 50% of the listing and are German brands, especially Volkswagen being the most popular brand listed.
#
# For significance of this analysis, we will only use brands that occupie more than 5% of total records.

# %%
brand_count = autos["brand"].value_counts(normalize=True)
sel_brand = brand_count[brand_count >= 0.05].index
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
mean_price_by_brand = {}

for b in sel_brand:
    mean_price = autos.loc[autos["brand"] == b, "price"].mean()
    mean_price_by_brand[b] = int(mean_price)
    
mean_price_by_brand
# Out:
# {'audi': 9336,
#  'bmw': 8332,
#  'ford': 3749,
#  'mercedes_benz': 8628,
#  'opel': 2975,
#  'volkswagen': 5402}

# %% [markdown]
# Corresponding to the brand disposition in the market, Audi, BMW and Mercedes has higher value for second hand cars. While Ford and Opel are on the low end spectrum. Volkswagen has a middle ground price point which is correlated to its popularity listed.

# %% [markdown]
# #### We are curious to aggregate the average mileage for each brand, to see if average mileage has a correlation with average price

# %%
mean_mileage_by_brand = {}

for b in sel_brand:
    mean_mileage = autos.loc[autos["brand"] == b, "odometer_km"].mean()
    mean_mileage_by_brand[b] = int(mean_mileage)
    
mean_mileage_by_brand
# Out:
# {'audi': 129157,
#  'bmw': 132572,
#  'ford': 124266,
#  'mercedes_benz': 130788,
#  'opel': 129310,
#  'volkswagen': 128707}

# %%
mpbrand_series = pd.Series(mean_price_by_brand).sort_values(ascending=False)
mpbrand_series
# Out:
# audi             9336
# bmw              8332
# ford             3749
# mercedes_benz    8628
# opel             2975
# volkswagen       5402
# dtype: int64

# %%
mmileage_series = pd.Series(mean_mileage_by_brand).sort_values(ascending=False)
mmileage_series
# Out:
# bmw              132572
# mercedes_benz    130788
# opel             129310
# audi             129157
# volkswagen       128707
# ford             124266
# dtype: int64

# %%
brand_pminfo = pd.DataFrame(mpbrand_series, columns=['mean_price'])

# %%
brand_pminfo
# Out:
#                mean_price
# audi                 9336
# bmw                  8332
# ford                 3749
# mercedes_benz        8628
# opel                 2975
# volkswagen           5402

# %%
brand_pminfo["mean_mileage"] = mmileage_series
brand_pminfo.sort_values(by='mean_price', ascending=False)
# Out:
#                mean_price  mean_mileage
# audi                 9336        129157
# mercedes_benz        8628        130788
# bmw                  8332        132572
# volkswagen           5402        128707
# ford                 3749        124266
# opel                 2975        129310

# %% [markdown]
# The average mileage are approximately the same among all brands.
#
# There isn't obvious correlation between the mileage and the price. The price difference are mainly related to the brand proposition in the market.
